# %% [markdown]
# # Human Brain Cell Types Analysis
# Compares the source taxonomies of the Whole Human Brain Ontology with the CxG integrated adult human brain dataset to evaluate their compatibility

# %%
## IMPORT depedencies 
#!{sys.executable} -m pip install hdf5plugin

import os
import shutil
import pandas as pd
import anndata as ad
import hdf5plugin
import numpy as np
import urllib.request as request
import zipfile

# %% [markdown]
# ## Read h5ad files

# %% [markdown]
# Please manually download the h5ad files from https://cellxgene.cziscience.com/collections/283d65eb-dd53-496d-adb7-7570c7caa443

# %%
ann_data_nn = ad.read_h5ad("h5ad-downloads/transcriptomic_diversity_of_cell_types_across_adult_human_brain_NN.h5ad", backed="r")
print(ann_data_nn.obs.shape)
ann_data_nn.obs.head(4)
# Out:
# (888263, 33)
#                                ROIGroup ROIGroupCoarse  ROIGroupFine  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  Hypothalamus   Hypothalamus  Hypothalamus
# 10X362_5:TCCGTGTGTGAAAGTT  Hypothalamus   Hypothalamus  Hypothalamus
# 10X362_5:CACGGGTAGAGCAGAA  Hypothalamus   Hypothalamus  Hypothalamus
# 10X362_5:GATTCTTGTATGTCAC  Hypothalamus   Hypothalamus  Hypothalamus
#
#                                 roi organism_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  Human MN            NCBITaxon:9606
# 10X362_5:TCCGTGTGTGAAAGTT  Human MN            NCBITaxon:9606
# 10X362_5:CACGGGTAGAGCAGAA  Human MN            NCBITaxon:9606
# 10X362_5:GATTCTTGTATGTCAC  Human MN            NCBITaxon:9606
#
#                           disease_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC             PATO:0000461
# 10X362_5:TCCGTGTGTGAAAGTT             PATO:0000461
# 10X362_5:CACGGGTAGAGCAGAA             PATO:0000461
# 10X362_5:GATTCTTGTATGTCAC             PATO:0000461
#
#                           self_reported_ethnicity_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                           HANCESTRO:0005
# 10X362_5:TCCGTGTGTGAAAGTT                           HANCESTRO:0005
# 10X362_5:CACGGGTAGAGCAGAA                           HANCESTRO:0005
# 10X362_5:GATTCTTGTATGTCAC                           HANCESTRO:0005
#
#                           assay_ontology_term_id sex_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC            EFO:0009922         PATO:0000384
# 10X362_5:TCCGTGTGTGAAAGTT            EFO:0009922         PATO:0000384
# 10X362_5:CACGGGTAGAGCAGAA            EFO:0009922         PATO:0000384
# 10X362_5:GATTCTTGTATGTCAC            EFO:0009922         PATO:0000384
#
#                           development_stage_ontology_term_id  ...  \
# CellID                                                        ...
# 10X362_3:TCAGTGAGTATTGACC                     HsapDv:0000123  ...
# 10X362_5:TCCGTGTGTGAAAGTT                     HsapDv:0000136  ...
# 10X362_5:CACGGGTAGAGCAGAA                     HsapDv:0000136  ...
# 10X362_5:GATTCTTGTATGTCAC                     HsapDv:0000136  ...
#
#                           tissue_ontology_term_id is_primary_data  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC          UBERON:0001898           False
# 10X362_5:TCCGTGTGTGAAAGTT          UBERON:0001898           False
# 10X362_5:CACGGGTAGAGCAGAA          UBERON:0001898           False
# 10X362_5:GATTCTTGTATGTCAC          UBERON:0001898           False
#
#                                  cell_type      assay  disease      organism  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  oligodendrocyte  10x 3' v3   normal  Homo sapiens
# 10X362_5:TCCGTGTGTGAAAGTT  oligodendrocyte  10x 3' v3   normal  Homo sapiens
# 10X362_5:CACGGGTAGAGCAGAA  oligodendrocyte  10x 3' v3   normal  Homo sapiens
# 10X362_5:GATTCTTGTATGTCAC  oligodendrocyte  10x 3' v3   normal  Homo sapiens
#
#                             sex        tissue self_reported_ethnicity  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  male  hypothalamus                European
# 10X362_5:TCCGTGTGTGAAAGTT  male  hypothalamus                European
# 10X362_5:CACGGGTAGAGCAGAA  male  hypothalamus                European
# 10X362_5:GATTCTTGTATGTCAC  male  hypothalamus                European
#
#                                  development_stage
# CellID
# 10X362_3:TCAGTGAGTATTGACC  29-year-old human stage
# 10X362_5:TCCGTGTGTGAAAGTT  42-year-old human stage
# 10X362_5:CACGGGTAGAGCAGAA  42-year-old human stage
# 10X362_5:GATTCTTGTATGTCAC  42-year-old human stage
#
# [4 rows x 33 columns]

# %% [markdown]
# ## Read cell_to_cell_set_assignments (c2c_data)
# Downloads, unzips, loads and merges the cell to cell set assingments data:

# %%
df_dtype = dict()
# df_dtype["sample_name"] = str
for i in range(1, 492):
    df_dtype["CS202210140_" + str(i)] = bool
def process_chunk(df):
    return df.astype(df_dtype)

# %%
## Human:
c2c_path = os.path.join(os.getcwd(), "h5ad-downloads/cell_to_cell_set_assignments_CS202210140.csv")
if not os.path.exists(c2c_path):
    # Unzip
    with zipfile.ZipFile(os.path.join(os.getcwd(), "h5ad-downloads/adult-human-brain_v1.zip"), 'r') as zip_ref:
        zip_ref.extractall(os.path.join(os.getcwd(), "h5ad-downloads/CS202210140/"))
shutil.copyfile(os.path.join(os.getcwd(), "h5ad-downloads/CS202210140/cell_to_cell_set_assignments.csv"), c2c_path)

processed_chunks = [] 

chunksize = 10 ** 5
with pd.read_csv(c2c_path, chunksize=chunksize) as reader:
    for chunk in reader:
        processed = process_chunk(chunk)
        processed_chunks.append(processed)
#         print(processed.dtypes)

c2c_human_data = pd.concat(processed_chunks)
print(c2c_human_data.shape)
# Out:
# (3369219, 493)

# %%
c2c_human_data.head(4)
# Out:
#                  sample_name  CS202210140_1  CS202210140_2  CS202210140_3  \
# 0  10X386_2:CATGGATTCTCGACGG           True          False          False
# 1  10X383_5:TCTTGCGGTGAATTGA           True          False          False
# 2  10X386_2:CTCATCGGTCGAGCAA           True          False          False
# 3  10X378_8:TTGGATGAGACAAGCC           True          False          False
#
#    CS202210140_4  CS202210140_5  CS202210140_6  CS202210140_7  CS202210140_8  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
#
#    CS202210140_9  ...  CS202210140_483  CS202210140_484  CS202210140_485  \
# 0          False  ...            False            False            False
# 1          False  ...            False            False            False
# 2          False  ...            False            False            False
# 3          False  ...            False            False            False
#
#    CS202210140_486  CS202210140_487  CS202210140_488  CS202210140_489  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
#
#    CS202210140_490  CS202210140_491  CS202210140_492
# 0            False            False                0
# 1            False            False                0
# 2            False            False                0
# 3            False            False                0
#
# [4 rows x 493 columns]
